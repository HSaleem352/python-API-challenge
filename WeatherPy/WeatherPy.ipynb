# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 565

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
url = f"{base_url}appid={weather_api_key}&units={units}&q="


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | quang ngai
# Processing Record 2 of Set 1 | west island
# Processing Record 3 of Set 1 | filipstad
# Processing Record 4 of Set 1 | sisimiut
# Processing Record 5 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 6 of Set 1 | cockburn town
# Processing Record 7 of Set 1 | wailua homesteads
# Processing Record 8 of Set 1 | pierre
# Processing Record 9 of Set 1 | nizhneangarsk
# Processing Record 10 of Set 1 | numan
# Processing Record 11 of Set 1 | iqaluit
# Processing Record 12 of Set 1 | mount gambier
# Processing Record 13 of Set 1 | quthing
# Processing Record 14 of Set 1 | vanimo
# Processing Record 15 of Set 1 | udachny
# Processing Record 16 of Set 1 | college
# Processing Record 17 of Set 1 | port-aux-francais
# Processing Record 18 of Set 1 | chonchi
# Processing Record 19 of Set 1 | lorengau
# Processing Record 20 of Set 1 | la ronge
# Processing Record 21 of Set 1 | n'zeto
# Processing Record 22 of Set 1 | vilyuchinsk
# Processing Record 23 of Set 1 | blackmans bay
# Processing Record 24 of Set 1 | simpang
# Processing Record 25 of Set 1 | jaru
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | adamstown
# Processing Record 28 of Set 1 | mount pearl
# Processing Record 29 of Set 1 | waitangi
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | todos santos
# Processing Record 32 of Set 1 | edinburgh of the seven seas
# Processing Record 33 of Set 1 | papatowai
# Processing Record 34 of Set 1 | arawa
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | whitehorse
# Processing Record 39 of Set 1 | komsomolets
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | ilulissat
# Processing Record 42 of Set 1 | tulun
# Processing Record 43 of Set 1 | jaicos
# Processing Record 44 of Set 1 | noumea
# Processing Record 45 of Set 1 | zhezqazghan
# Processing Record 46 of Set 1 | margaret river
# Processing Record 47 of Set 1 | gadzhiyevo
# Processing Record 48 of Set 1 | afaahiti
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 0 of Set 2 | poronaysk
# Processing Record 1 of Set 2 | mogocha
# Processing Record 2 of Set 2 | san patricio
# Processing Record 3 of Set 2 | grytviken
# Processing Record 4 of Set 2 | gaspe
# Processing Record 5 of Set 2 | smithers
# Processing Record 6 of Set 2 | hobyo
# Processing Record 7 of Set 2 | saint-jean-de-monts
# Processing Record 8 of Set 2 | christchurch
# Processing Record 9 of Set 2 | rongelap
# Processing Record 10 of Set 2 | anahuac
# Processing Record 11 of Set 2 | centerville
# Processing Record 12 of Set 2 | laayoune plage
# City not found. Skipping...
# Processing Record 13 of Set 2 | bilibino
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | stanley
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | newman
# Processing Record 18 of Set 2 | laascaanood
# Processing Record 19 of Set 2 | mar del plata
# Processing Record 20 of Set 2 | grand falls-windsor
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | solnechnyy
# Processing Record 23 of Set 2 | sabang
# Processing Record 24 of Set 2 | griffith
# Processing Record 25 of Set 2 | necochea
# Processing Record 26 of Set 2 | puerto natales
# Processing Record 27 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 28 of Set 2 | cabo san lucas
# Processing Record 29 of Set 2 | sligo
# Processing Record 30 of Set 2 | dudinka
# Processing Record 31 of Set 2 | yamba
# Processing Record 32 of Set 2 | rio grande
# Processing Record 33 of Set 2 | new norfolk
# Processing Record 34 of Set 2 | holualoa
# Processing Record 35 of Set 2 | saipan
# Processing Record 36 of Set 2 | fisterra
# Processing Record 37 of Set 2 | anadyr
# Processing Record 38 of Set 2 | coos bay
# Processing Record 39 of Set 2 | toamasina
# Processing Record 40 of Set 2 | pahrump
# Processing Record 41 of Set 2 | talnakh
# Processing Record 42 of Set 2 | colac
# Processing Record 43 of Set 2 | kabalo
# Processing Record 44 of Set 2 | pekanbaru
# Processing Record 45 of Set 2 | ushuaia
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | macau
# Processing Record 48 of Set 2 | sant julia de loria
# Processing Record 49 of Set 2 | jiuquan
# Processing Record 0 of Set 3 | georgetown
# Processing Record 1 of Set 3 | springbok
# Processing Record 2 of Set 3 | nova sintra
# Processing Record 3 of Set 3 | olonkinbyen
# Processing Record 4 of Set 3 | tazovsky
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | bubaque
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | tsiombe
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | fort st. john
# Processing Record 11 of Set 3 | fruita
# Processing Record 12 of Set 3 | isafjordur
# Processing Record 13 of Set 3 | i-n-salah
# Processing Record 14 of Set 3 | port alfred
# Processing Record 15 of Set 3 | auki
# Processing Record 16 of Set 3 | kitimat
# Processing Record 17 of Set 3 | vorgashor
# Processing Record 18 of Set 3 | alvorada
# Processing Record 19 of Set 3 | dadukou
# Processing Record 20 of Set 3 | lospalos
# Processing Record 21 of Set 3 | quimili
# Processing Record 22 of Set 3 | kapa'a
# Processing Record 23 of Set 3 | luderitz
# Processing Record 24 of Set 3 | benjamin constant
# Processing Record 25 of Set 3 | haiku-pauwela
# Processing Record 26 of Set 3 | greymouth
# Processing Record 27 of Set 3 | albany
# Processing Record 28 of Set 3 | nar'yan-mar
# Processing Record 29 of Set 3 | saint-pierre
# Processing Record 30 of Set 3 | g'uzor
# Processing Record 31 of Set 3 | kirakira
# Processing Record 32 of Set 3 | blackwater
# Processing Record 33 of Set 3 | letlhakane
# Processing Record 34 of Set 3 | palikir - national government center
# Processing Record 35 of Set 3 | newport
# Processing Record 36 of Set 3 | arkhangel'sk
# Processing Record 37 of Set 3 | vadso
# Processing Record 38 of Set 3 | verkh-chebula
# Processing Record 39 of Set 3 | tafuna
# Processing Record 40 of Set 3 | el calafate
# Processing Record 41 of Set 3 | praya
# Processing Record 42 of Set 3 | utrik
# Processing Record 43 of Set 3 | caconda
# Processing Record 44 of Set 3 | novoarkhanhel's'k
# Processing Record 45 of Set 3 | cidreira
# Processing Record 46 of Set 3 | mong cai
# City not found. Skipping...
# Processing Record 47 of Set 3 | san antonio de pale
# Processing Record 48 of Set 3 | hamilton
# Processing Record 49 of Set 3 | tralee
# Processing Record 0 of Set 4 | tamanrasset
# Processing Record 1 of Set 4 | kattivakkam
# Processing Record 2 of Set 4 | espargos
# City not found. Skipping...
# Processing Record 3 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 4 of Set 4 | cadale
# Processing Record 5 of Set 4 | castillos
# Processing Record 6 of Set 4 | flying fish cove
# Processing Record 7 of Set 4 | nova vicosa
# Processing Record 8 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 9 of Set 4 | la passe
# Processing Record 10 of Set 4 | arys
# Processing Record 11 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 12 of Set 4 | tabuk
# Processing Record 13 of Set 4 | port mathurin
# Processing Record 14 of Set 4 | mizdah
# Processing Record 15 of Set 4 | alofi
# Processing Record 16 of Set 4 | catumbela
# Processing Record 17 of Set 4 | sars
# Processing Record 18 of Set 4 | aykhal
# Processing Record 19 of Set 4 | angaur state
# Processing Record 20 of Set 4 | pinsk
# Processing Record 21 of Set 4 | aasiaat
# Processing Record 22 of Set 4 | lionel town
# Processing Record 23 of Set 4 | nagqu
# Processing Record 24 of Set 4 | nelson
# Processing Record 25 of Set 4 | piton saint-leu
# Processing Record 26 of Set 4 | tibagi
# Processing Record 27 of Set 4 | santa cruz
# Processing Record 28 of Set 4 | sooke
# Processing Record 29 of Set 4 | sepuka
# Processing Record 30 of Set 4 | oodweyne
# Processing Record 31 of Set 4 | al mindak
# Processing Record 32 of Set 4 | at taj
# Processing Record 33 of Set 4 | seybaplaya
# Processing Record 34 of Set 4 | coquimbo
# Processing Record 35 of Set 4 | wulingyuan
# Processing Record 36 of Set 4 | ola
# Processing Record 37 of Set 4 | watsa
# Processing Record 38 of Set 4 | heroica guaymas
# Processing Record 39 of Set 4 | fale old settlement
# Processing Record 40 of Set 4 | hawaiian paradise park
# Processing Record 41 of Set 4 | saldanha
# Processing Record 42 of Set 4 | seminole
# Processing Record 43 of Set 4 | rozhniv
# Processing Record 44 of Set 4 | igarka
# Processing Record 45 of Set 4 | badger
# Processing Record 46 of Set 4 | maria la baja
# Processing Record 47 of Set 4 | damongo
# City not found. Skipping...
# Processing Record 48 of Set 4 | touros
# Processing Record 49 of Set 4 | strelka
# Processing Record 0 of Set 5 | tot'ma
# Processing Record 1 of Set 5 | enewetak
# Processing Record 2 of Set 5 | gokceada
# Processing Record 3 of Set 5 | kirensk
# Processing Record 4 of Set 5 | ploneour-lanvern
# Processing Record 5 of Set 5 | bodo
# Processing Record 6 of Set 5 | olyokminsk
# Processing Record 7 of Set 5 | kavieng
# Processing Record 8 of Set 5 | tura
# Processing Record 9 of Set 5 | aswan
# Processing Record 10 of Set 5 | lamu
# Processing Record 11 of Set 5 | naze
# Processing Record 12 of Set 5 | madang
# Processing Record 13 of Set 5 | st. john's
# Processing Record 14 of Set 5 | jianguang
# Processing Record 15 of Set 5 | suva
# Processing Record 16 of Set 5 | kencong
# Processing Record 17 of Set 5 | axim
# Processing Record 18 of Set 5 | khorinsk
# Processing Record 19 of Set 5 | cheremukhovo
# Processing Record 20 of Set 5 | kruisfontein
# Processing Record 21 of Set 5 | novoagansk
# Processing Record 22 of Set 5 | floro
# Processing Record 23 of Set 5 | gemena
# Processing Record 24 of Set 5 | mutare
# Processing Record 25 of Set 5 | bengkulu
# Processing Record 26 of Set 5 | horta
# Processing Record 27 of Set 5 | carutapera
# Processing Record 28 of Set 5 | port elizabeth
# Processing Record 29 of Set 5 | lichuan
# Processing Record 30 of Set 5 | tepeapulco
# Processing Record 31 of Set 5 | bamboo flat
# Processing Record 32 of Set 5 | buchanan
# Processing Record 33 of Set 5 | bratsk
# Processing Record 34 of Set 5 | humahuaca
# Processing Record 35 of Set 5 | ayaguz
# City not found. Skipping...
# Processing Record 36 of Set 5 | constantia
# Processing Record 37 of Set 5 | ponta delgada
# Processing Record 38 of Set 5 | uturoa
# Processing Record 39 of Set 5 | fortuna
# Processing Record 40 of Set 5 | praia
# Processing Record 41 of Set 5 | kiruna
# Processing Record 42 of Set 5 | toliara
# Processing Record 43 of Set 5 | ust-nera
# Processing Record 44 of Set 5 | tobi village
# City not found. Skipping...
# Processing Record 45 of Set 5 | bomaderry
# Processing Record 46 of Set 5 | kolosovka
# Processing Record 47 of Set 5 | anna regina
# Processing Record 48 of Set 5 | troyan
# Processing Record 49 of Set 5 | fort bragg
# Processing Record 0 of Set 6 | hammerfest
# Processing Record 1 of Set 6 | tubay
# Processing Record 2 of Set 6 | paramonga
# Processing Record 3 of Set 6 | tofol
# Processing Record 4 of Set 6 | esikhaleni
# Processing Record 5 of Set 6 | ghat
# Processing Record 6 of Set 6 | qaqortoq
# Processing Record 7 of Set 6 | murun-kuren
# Processing Record 8 of Set 6 | san francisco
# Processing Record 9 of Set 6 | brookings
# Processing Record 10 of Set 6 | sadjoavato
# City not found. Skipping...
# Processing Record 11 of Set 6 | bernkastel-kues
# Processing Record 12 of Set 6 | alice springs
# Processing Record 13 of Set 6 | santa terezinha
# Processing Record 14 of Set 6 | mosjoen
# Processing Record 15 of Set 6 | la haute-saint-charles
# City not found. Skipping...
# Processing Record 16 of Set 6 | saint-francois
# Processing Record 17 of Set 6 | aegina
# Processing Record 18 of Set 6 | nemuro
# Processing Record 19 of Set 6 | sitka
# Processing Record 20 of Set 6 | hadibu
# Processing Record 21 of Set 6 | yagry
# City not found. Skipping...
# Processing Record 22 of Set 6 | rikaze
# Processing Record 23 of Set 6 | nuuk
# Processing Record 24 of Set 6 | akhmet'a
# Processing Record 25 of Set 6 | ylitornio
# Processing Record 26 of Set 6 | masumbwe
# Processing Record 27 of Set 6 | jolo
# Processing Record 28 of Set 6 | honefoss
# Processing Record 29 of Set 6 | hollister
# Processing Record 30 of Set 6 | montanha
# Processing Record 31 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 32 of Set 6 | barkly west
# Processing Record 33 of Set 6 | tashla
# Processing Record 34 of Set 6 | turbo
# Processing Record 35 of Set 6 | kailua-kona
# Processing Record 36 of Set 6 | nabire
# Processing Record 37 of Set 6 | turochak
# Processing Record 38 of Set 6 | general pico
# Processing Record 39 of Set 6 | merizo village
# Processing Record 40 of Set 6 | bria
# Processing Record 41 of Set 6 | miyaly
# Processing Record 42 of Set 6 | atyrau
# Processing Record 43 of Set 6 | bayana
# Processing Record 44 of Set 6 | korla
# Processing Record 45 of Set 6 | monrovia
# Processing Record 46 of Set 6 | alaghsas
# Processing Record 47 of Set 6 | pisco
# Processing Record 48 of Set 6 | abashiri
# Processing Record 49 of Set 6 | itaituba
# Processing Record 0 of Set 7 | nueve de julio
# Processing Record 1 of Set 7 | kalemie
# Processing Record 2 of Set 7 | villa zempoala
# Processing Record 3 of Set 7 | atafu village
# Processing Record 4 of Set 7 | kresttsy
# Processing Record 5 of Set 7 | port saint john's
# Processing Record 6 of Set 7 | crane
# Processing Record 7 of Set 7 | la seu d'urgell
# Processing Record 8 of Set 7 | ataq
# Processing Record 9 of Set 7 | santarem
# Processing Record 10 of Set 7 | howrah
# Processing Record 11 of Set 7 | okhotsk
# Processing Record 12 of Set 7 | vengerovo
# Processing Record 13 of Set 7 | akureyri
# Processing Record 14 of Set 7 | soio
# Processing Record 15 of Set 7 | talara
# Processing Record 16 of Set 7 | union choco
# City not found. Skipping...
# Processing Record 17 of Set 7 | medina
# Processing Record 18 of Set 7 | praia da vitoria
# Processing Record 19 of Set 7 | iskateley
# Processing Record 20 of Set 7 | tuy hoa
# Processing Record 21 of Set 7 | katsuren-haebaru
# Processing Record 22 of Set 7 | malango
# Processing Record 23 of Set 7 | kapoeta
# Processing Record 24 of Set 7 | san julian
# Processing Record 25 of Set 7 | sinjar
# Processing Record 26 of Set 7 | al majaridah
# Processing Record 27 of Set 7 | yermentau
# Processing Record 28 of Set 7 | tutoia
# Processing Record 29 of Set 7 | el porvenir
# Processing Record 30 of Set 7 | uffenheim
# Processing Record 31 of Set 7 | port lincoln
# Processing Record 32 of Set 7 | papao
# Processing Record 33 of Set 7 | jiagedaqi
# Processing Record 34 of Set 7 | wenchang
# Processing Record 35 of Set 7 | tocopilla
# Processing Record 36 of Set 7 | ranohira
# City not found. Skipping...
# Processing Record 37 of Set 7 | carbonear
# Processing Record 38 of Set 7 | tindouf
# Processing Record 39 of Set 7 | molde
# Processing Record 40 of Set 7 | lompoc
# Processing Record 41 of Set 7 | nampa
# Processing Record 42 of Set 7 | lihue
# Processing Record 43 of Set 7 | viedma
# Processing Record 44 of Set 7 | belyy yar
# Processing Record 45 of Set 7 | labrador city
# Processing Record 46 of Set 7 | tazacorte
# Processing Record 47 of Set 7 | terra rica
# Processing Record 48 of Set 7 | lethem
# Processing Record 49 of Set 7 | gejiu
# Processing Record 0 of Set 8 | sulak
# Processing Record 1 of Set 8 | amahai
# Processing Record 2 of Set 8 | merikanjaka
# City not found. Skipping...
# Processing Record 3 of Set 8 | ndago
# Processing Record 4 of Set 8 | kismayo
# Processing Record 5 of Set 8 | itamaraca
# Processing Record 6 of Set 8 | male
# Processing Record 7 of Set 8 | san pedro de uraba
# Processing Record 8 of Set 8 | batangafo
# Processing Record 9 of Set 8 | kidal
# Processing Record 10 of Set 8 | pangoa
# Processing Record 11 of Set 8 | hadithah
# Processing Record 12 of Set 8 | mana
# Processing Record 13 of Set 8 | invercargill
# Processing Record 14 of Set 8 | kingston
# Processing Record 15 of Set 8 | tanjung selor
# City not found. Skipping...
# Processing Record 16 of Set 8 | kavaratti
# Processing Record 17 of Set 8 | salekhard
# Processing Record 18 of Set 8 | kataragama
# City not found. Skipping...
# Processing Record 19 of Set 8 | kremmen
# Processing Record 20 of Set 8 | toyooka
# Processing Record 21 of Set 8 | prince rupert
# Processing Record 22 of Set 8 | saint-philippe
# Processing Record 23 of Set 8 | balqash
# Processing Record 24 of Set 8 | minas de marcona
# Processing Record 25 of Set 8 | bayanaul
# Processing Record 26 of Set 8 | batifa
# City not found. Skipping...
# Processing Record 27 of Set 8 | vilyuysk
# Processing Record 28 of Set 8 | pitimbu
# Processing Record 29 of Set 8 | port blair
# Processing Record 30 of Set 8 | miyanoura
# City not found. Skipping...
# Processing Record 31 of Set 8 | mazagao
# Processing Record 32 of Set 8 | borovskoy
# Processing Record 33 of Set 8 | sur
# Processing Record 34 of Set 8 | vila velha
# Processing Record 35 of Set 8 | filey
# Processing Record 36 of Set 8 | happy valley-goose bay
# Processing Record 37 of Set 8 | puerto baquerizo moreno
# Processing Record 38 of Set 8 | queenstown
# Processing Record 39 of Set 8 | kanker
# Processing Record 40 of Set 8 | ape
# Processing Record 41 of Set 8 | masaki-cho
# Processing Record 42 of Set 8 | harper
# Processing Record 43 of Set 8 | khao yoi
# Processing Record 44 of Set 8 | bich'vinta
# Processing Record 45 of Set 8 | changji
# Processing Record 46 of Set 8 | ancud
# Processing Record 47 of Set 8 | coyhaique
# Processing Record 48 of Set 8 | qujing
# Processing Record 49 of Set 8 | urucuca
# Processing Record 0 of Set 9 | broken hill
# Processing Record 1 of Set 9 | port douglas
# Processing Record 2 of Set 9 | porto novo
# Processing Record 3 of Set 9 | al muwayh
# Processing Record 4 of Set 9 | esmeraldas
# Processing Record 5 of Set 9 | nova xavantina
# Processing Record 6 of Set 9 | langres
# Processing Record 7 of Set 9 | klyuchi
# Processing Record 8 of Set 9 | manokwari
# Processing Record 9 of Set 9 | fernie
# Processing Record 10 of Set 9 | krasnaya yaruga
# Processing Record 11 of Set 9 | kununurra
# Processing Record 12 of Set 9 | fort-shevchenko
# Processing Record 13 of Set 9 | mtskheta
# Processing Record 14 of Set 9 | shumikha
# Processing Record 15 of Set 9 | bati
# Processing Record 16 of Set 9 | afif
# Processing Record 17 of Set 9 | sao joao da barra
# Processing Record 18 of Set 9 | port shepstone
# Processing Record 19 of Set 9 | bayanhongor
# Processing Record 20 of Set 9 | kendari
# Processing Record 21 of Set 9 | pamandzi
# Processing Record 22 of Set 9 | hasaki
# Processing Record 23 of Set 9 | kone
# Processing Record 24 of Set 9 | leeton
# Processing Record 25 of Set 9 | amungan
# Processing Record 26 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 9 | dhidhdhoo
# Processing Record 28 of Set 9 | geraldton
# Processing Record 29 of Set 9 | sadri
# Processing Record 30 of Set 9 | kemijarvi
# Processing Record 31 of Set 9 | tolanaro
# Processing Record 32 of Set 9 | lunavada
# Processing Record 33 of Set 9 | portland
# Processing Record 34 of Set 9 | camocim
# Processing Record 35 of Set 9 | fort irwin
# Processing Record 36 of Set 9 | itoman
# Processing Record 37 of Set 9 | mehar
# Processing Record 38 of Set 9 | smidovich
# Processing Record 39 of Set 9 | labytnangi
# Processing Record 40 of Set 9 | zigong
# Processing Record 41 of Set 9 | paita
# Processing Record 42 of Set 9 | walvis bay
# Processing Record 43 of Set 9 | hiratacho
# Processing Record 44 of Set 9 | puerto lempira
# Processing Record 45 of Set 9 | moura
# Processing Record 46 of Set 9 | quiindy
# Processing Record 47 of Set 9 | 'anah
# City not found. Skipping...
# Processing Record 48 of Set 9 | waimea
# Processing Record 49 of Set 9 | timbuktu
# Processing Record 0 of Set 10 | karratha
# Processing Record 1 of Set 10 | broome
# Processing Record 2 of Set 10 | buritizeiro
# Processing Record 3 of Set 10 | mbandaka
# Processing Record 4 of Set 10 | tayu
# Processing Record 5 of Set 10 | olinda
# Processing Record 6 of Set 10 | san andres
# Processing Record 7 of Set 10 | kargil
# Processing Record 8 of Set 10 | kyzylorda
# Processing Record 9 of Set 10 | kerikeri
# Processing Record 10 of Set 10 | vorkuta
# Processing Record 11 of Set 10 | barcelos
# Processing Record 12 of Set 10 | ballina
# Processing Record 13 of Set 10 | baley
# Processing Record 14 of Set 10 | lazaro cardenas
# Processing Record 15 of Set 10 | glubokiy
# Processing Record 16 of Set 10 | neiafu
# Processing Record 17 of Set 10 | puerto deseado
# Processing Record 18 of Set 10 | katsuura
# Processing Record 19 of Set 10 | prince george
# Processing Record 20 of Set 10 | dingras
# Processing Record 21 of Set 10 | tangalle
# Processing Record 22 of Set 10 | kurumkan
# Processing Record 23 of Set 10 | wainwright
# Processing Record 24 of Set 10 | qarqaraly
# Processing Record 25 of Set 10 | ghazni
# Processing Record 26 of Set 10 | ouellah
# City not found. Skipping...
# Processing Record 27 of Set 10 | tacuarembo
# Processing Record 28 of Set 10 | port augusta
# Processing Record 29 of Set 10 | kutum
# Processing Record 30 of Set 10 | mantua
# Processing Record 31 of Set 10 | nelson bay
# Processing Record 32 of Set 10 | chiredzi
# Processing Record 33 of Set 10 | kalifornsky
# Processing Record 34 of Set 10 | kratie
# Processing Record 35 of Set 10 | punta cana
# Processing Record 36 of Set 10 | taunggyi
# Processing Record 37 of Set 10 | yeppoon
# Processing Record 38 of Set 10 | yany kapu
# City not found. Skipping...
# Processing Record 39 of Set 10 | roccella ionica
# Processing Record 40 of Set 10 | yurty
# Processing Record 41 of Set 10 | rockport
# Processing Record 42 of Set 10 | egilsstadir
# Processing Record 43 of Set 10 | belmonte
# Processing Record 44 of Set 10 | al harithah
# Processing Record 45 of Set 10 | butig
# Processing Record 46 of Set 10 | fatehpur
# Processing Record 47 of Set 10 | uelsen
# Processing Record 48 of Set 10 | bijar
# Processing Record 49 of Set 10 | yangor
# City not found. Skipping...
# Processing Record 0 of Set 11 | zhangjiakou shi xuanhua qu
# Processing Record 1 of Set 11 | thompson
# Processing Record 2 of Set 11 | richfield
# Processing Record 3 of Set 11 | kiffa
# Processing Record 4 of Set 11 | machina
# Processing Record 5 of Set 11 | jayapura
# Processing Record 6 of Set 11 | yanga
# Processing Record 7 of Set 11 | mobaye
# Processing Record 8 of Set 11 | al burayqah
# Processing Record 9 of Set 11 | genhe
# Processing Record 10 of Set 11 | chiavari
# Processing Record 11 of Set 11 | ceeldheer
# Processing Record 12 of Set 11 | hilo
# Processing Record 13 of Set 11 | illizi
# Processing Record 14 of Set 11 | ta`u
# Processing Record 15 of Set 11 | celestun
# Processing Record 16 of Set 11 | richards bay
# Processing Record 17 of Set 11 | zagora
# Processing Record 18 of Set 11 | pacific grove
# Processing Record 19 of Set 11 | bougouni
# Processing Record 20 of Set 11 | coahuayana de hidalgo
# Processing Record 21 of Set 11 | airway heights
# Processing Record 22 of Set 11 | vernon
# Processing Record 23 of Set 11 | grajau
# Processing Record 24 of Set 11 | sola
# Processing Record 25 of Set 11 | northam
# Processing Record 26 of Set 11 | hithadhoo
# Processing Record 27 of Set 11 | boa vista
# Processing Record 28 of Set 11 | brak
# Processing Record 29 of Set 11 | mahibadhoo
# Processing Record 30 of Set 11 | mangrol
# Processing Record 31 of Set 11 | newberry
# Processing Record 32 of Set 11 | moissala
# Processing Record 33 of Set 11 | san gabriel
# Processing Record 34 of Set 11 | colonia
# Processing Record 35 of Set 11 | elko
# Processing Record 36 of Set 11 | yarmouth
# Processing Record 37 of Set 11 | bardsir
# Processing Record 38 of Set 11 | mthatha
# Processing Record 39 of Set 11 | lock haven
# Processing Record 40 of Set 11 | bulog
# Processing Record 41 of Set 11 | skeldon
# Processing Record 42 of Set 11 | ugoofaaru
# Processing Record 43 of Set 11 | parabel'
# Processing Record 44 of Set 11 | turpan
# Processing Record 45 of Set 11 | kamen'-na-obi
# Processing Record 46 of Set 11 | gebeit
# Processing Record 47 of Set 11 | orshanka
# Processing Record 48 of Set 11 | jutai
# Processing Record 49 of Set 11 | north battleford
# Processing Record 0 of Set 12 | vryburg
# Processing Record 1 of Set 12 | chui
# Processing Record 2 of Set 12 | hammond
# Processing Record 3 of Set 12 | xilin hot
# Processing Record 4 of Set 12 | ust'-ilimsk
# Processing Record 5 of Set 12 | mathba
# Processing Record 6 of Set 12 | tlahualilo de zaragoza
# Processing Record 7 of Set 12 | colonia menno
# Processing Record 8 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 12 | conde
# Processing Record 10 of Set 12 | parauna
# Processing Record 11 of Set 12 | healesville
# Processing Record 12 of Set 12 | keflavik
# Processing Record 13 of Set 12 | codrington
# Processing Record 14 of Set 12 | glace bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          537
# Lat           537
# Lng           537
# Max Temp      537
# Humidity      537
# Cloudiness    537
# Wind Speed    537
# Country       537
# Date          537
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     quang ngai  15.1167  108.8000     22.76        93          33
# 1    west island -12.1568   96.8225     25.99        83          40
# 2      filipstad  59.7124   14.1683    -14.01        95          15
# 3       sisimiut  66.9395  -53.6735    -10.53        77          18
# 4  cockburn town  21.4612  -71.1419     27.30        78           6
#
#    Wind Speed Country        Date
# 0        1.18      VN  1701816301
# 1        2.57      CC  1701816302
# 2        0.92      SE  1701816302
# 3        5.13      GL  1701816302
# 4        6.30      TC  1701816068

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           quang ngai  15.1167  108.8000     22.76        93          33
# 1          west island -12.1568   96.8225     25.99        83          40
# 2            filipstad  59.7124   14.1683    -14.01        95          15
# 3             sisimiut  66.9395  -53.6735    -10.53        77          18
# 4        cockburn town  21.4612  -71.1419     27.30        78           6
#
#          Wind Speed Country        Date
# City_ID
# 0              1.18      VN  1701816301
# 1              2.57      CC  1701816302
# 2              0.92      SE  1701816302
# 3              5.13      GL  1701816302
# 4              6.30      TC  1701816068

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'])

# Incorporate the other graph properties
plt.title(f"City Latitude VS Max Temperature")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'])

# Incorporate the other graph properties
plt.title(f"City Latitude VS Humidity (%)")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'])

# Incorporate the other graph properties
plt.title(f"City Latitude VS Cloudiness (%)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'])

# Incorporate the other graph properties
plt.title(f"City Latitude VS Windspeed")
plt.xlabel('Latitude')
plt.ylabel('Windspeed (m/s)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_reg_func(df, param):
    x_values = df['Lat']
    y_values = df[param]
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    print(f"The r-value is: {rvalue**2}")
    
    plt.scatter(x_values, y_values)
    plt.plot(x_values,regress_values,"r-")
    
    plt.xlabel('Latitude')
    plt.ylabel(param)
        
    return line_eq

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df['Lat'] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               quang ngai  15.1167  108.8000     22.76        93          33
# 2                filipstad  59.7124   14.1683    -14.01        95          15
# 3                 sisimiut  66.9395  -53.6735    -10.53        77          18
# 4            cockburn town  21.4612  -71.1419     27.30        78           6
# 5        wailua homesteads  22.0669 -159.3780     27.24        81          40
#
#          Wind Speed Country        Date
# City_ID
# 0              1.18      VN  1701816301
# 2              0.92      SE  1701816302
# 3              5.13      GL  1701816302
# 4              6.30      TC  1701816068
# 5              8.75      US  1701816303

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df['Lat'] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1              west island -12.1568   96.8225     25.99        83          40
# 10           mount gambier -37.8333  140.7667     17.74        49          96
# 11                 quthing -30.4000   27.7003     13.99        67          34
# 12                  vanimo  -2.6741  141.3028     27.62        81          79
# 15       port-aux-francais -49.3500   70.2167      5.90        99         100
#
#          Wind Speed Country        Date
# City_ID
# 1              2.57      CC  1701816302
# 10             0.88      AU  1701816128
# 11             3.41      LS  1701816304
# 12             1.41      PG  1701816304
# 15             9.28      TF  1701816305

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

tempvslat_N = lin_reg_func(northern_hemi_df,'Max Temp')

plt.annotate(tempvslat_N,(5,-40),fontsize=15,color="red")
plt.show()
# Out:
# The r-value is: 0.7401587270143494

# %%
# Linear regression on Southern Hemisphere
tempvslat_S = lin_reg_func(southern_hemi_df,'Max Temp')

plt.annotate(tempvslat_S,(-30,5),fontsize=15,color="red")
plt.show()
# Out:
# The r-value is: 0.47207346148085855

# %% [markdown]
# **Discussion about the linear relationship:**
# The linear regression model for the Nothern Hemisphere is negative compared to the Southern Hemisphere. This suggests that the temperature decreases when moving away from the equator. The correlation between the temperature and nothern hemisphere is strong but the correlation for the southern hemisphere is weak.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
humvslat_N = lin_reg_func(northern_hemi_df,'Humidity')

plt.annotate(humvslat_N,(40,10),fontsize=15,color="red")
plt.show()
# Out:
# The r-value is: 0.11214009103896015

# %%
# Southern Hemisphere
humvslat_S = lin_reg_func(southern_hemi_df,'Humidity')

plt.annotate(humvslat_S,(-55,20),fontsize=15,color="red")
plt.show()
# Out:
# The r-value is: 0.11967368502836301

# %% [markdown]
# **Discussion about the linear relationship:**
# The scatter plot is all over the plot. The linear regression model doesnt seem to be accurate with these plots since the correlation is also extremely weak. Humidity does not seem to be related to the latitude in the nothern not the southern hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
cldvslat_N = lin_reg_func(northern_hemi_df,'Cloudiness')

plt.annotate(cldvslat_N,(40, 30),fontsize=15,color="red")
plt.show()
# Out:
# The r-value is: 0.042617686103630106

# %%
# Southern Hemisphere
cldvslat_S = lin_reg_func(southern_hemi_df,'Cloudiness')

plt.annotate(cldvslat_S,(-55, 45),fontsize=15,color="red")
plt.show()
# Out:
# The r-value is: 0.015157550064378088

# %% [markdown]
# **Discussion about the linear relationship:**
# The scatter points are all over the plot. The correlation is also extremely low which suggests that cloudiness is not related to the latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
windvslat_N = lin_reg_func(northern_hemi_df,'Wind Speed')

plt.annotate(windvslat_N,(0, 12),fontsize=15,color="red")
plt.show()
# Out:
# The r-value is: 0.004024340958447285

# %%
# Southern Hemisphere
windvslat_S = lin_reg_func(southern_hemi_df,'Wind Speed')

plt.annotate(windvslat_S,(-30, 15),fontsize=15,color="red")
plt.show()
# Out:
# The r-value is: 0.10500947504112623

# %% [markdown]
# **Discussion about the linear relationship:**
# There doesnt seem to be any direct correlation between wind speed and the latitude as the regression model is not accurate. However, it can be noticed that the extreme wind speeds occur in latitudes farthest away from the equator.
